# %% [markdown]
# # Designing Information With Jupyter Notebooks
# ##### Initializing an instance of an AI client is an effective means of performs various forms of AI-enabled research.
# #### Here's quick example of how to use a Jupyter Notebook:

# %%
# The code below defines a variable "x" as equal to the number 4.
x = 4

# The code below defines a variable "y" as equal to the number 2.
y= 2

# The "print" function is a built-in function and simply 'prints' an output.
print("As you can see, x =", x,"and y =", y,".")
# Out:
# As you can see, x = 4 and y = 2 .

# %%
# In this example, an expression that calculates the sum of x and y is passed
# as a parameter to the 'print' function which concatenates the listed values.
print("The sum of", x,"and", y,"is", x+y)
# Out:
# The sum of 4 and 2 is 6

# %%
# Variables are shared between cells in a Jupyter Notebook.
# For example, the variables in prior cells are accessible in subsequent cells
print("x is",x,"and y is",y)
# Out:
# x is 4 and y is 2

# %%
# By breaking down problems into sub-problems, we can develop piecewise solutions to 
# difficult problems.
a=1
b=2
c=(a**2+b**2)**(1/2)
d="John Doe"
e="lead analyst"
f="Accounting"

print("The hypotenuse of a right triangle with adjacent dimensions of",a,"and",b,"is",c,"\n",
      "according to a numerical analysis conducted by",d,",",e,"from our",f,"division.")
# Out:
# The hypotenuse of a right triangle with adjacent dimensions of 1 and 2 is 2.23606797749979
#  according to a numerical analysis conducted by John Doe , lead analyst from our Accounting division.

# %% [markdown]
# ##### Another great feature is the capacity to intermingle markdown language with code snippets! This allows users to conduct data science and comparative analysis. One collection of cells can request raw data...

# %%
# an example of a variable containing url to an endpoint.
url = "https://public.tableau.com/app/sample-data/sample_-_superstore.xls"

# a basic example of a web-client implementation and output.
def http_client(url):
    print("fetching data...")
    return "response data found!"

# an example of a 'method' implementation that returns a value from the given endpoint. 
response = http_client(url)

print(response)
# Out:
# fetching data...
# response data found!

# %% [markdown]
# ##### ... while the next "cleans" the returned data.

# %%
# an example of a 'payload' encapsulated within a 'response' object returned by a web client.
response = {"payload":"valuable data here!", "other":"worthless data here..."}

# assigning the 'payload' to a variable.
raw_data = response['payload']

# defing a function to 'clean' the raw data.
def clean(payload):
    print("Cleaning payload...")
    return payload

# applying the 'clean' method to the 'raw_data' variable.
clean_data = clean(raw_data)

# printing the results
print("Cleaned data:", clean_data)
# Out:
# Cleaning payload...
# Cleaned data: valuable data here!

# %% [markdown]
# ##### After normalizing the data, we can develop a 'pipeline' for further transformations. With each successive procedure, the input acquires characteristics of the intended output.

# %% [markdown]
# Let's see a practical demonstration.

# %% [markdown]
# Libraries are curated collections of related classes and methods that together provide resources for other developers to use in their applications. They are often specialized by application, for example the library "requests" is a popular http webclient constructor. A constructor is a term for a method that creates instances of a given application. The requests library provides mechanisms for connecting an application to the internet. How it does so is beyond the scope of this demonstration.

# %%
# We will need a few different libraries for this demonstration, each providing a different suite of capabilities to use in the 
# application. Requests provides connectivity, Numpy provides useful mathematical tools, Matplotlib provides a data visualization 
# library, Pandas for constructing data models, and Sklearn for data processing. We can import them all in a single line of code:
import requests, numpy, matplotlib.pyplot as plt, pandas as pd, sklearn

# %%
# So for this demo, we're gonna need some data which we'll get from tableau. Professional developers of popular libraries 
# often maintain a website to provide usage instructions. 
url = "https://public.tableau.com/app/sample-data/Data%20Set-%20Inc5000%20Company%20List_2014.csv"

# We can load the data from the source directly into a dataframe using Pandas.
df = pd.read_csv(url)

# A dataframe is a data structure that can be used for data manipulation and have many built-in methods and properties.
df.head(3)
# Out:
#    _input  _num           _widgetName               _source  _resultNumber  \
# 0     NaN     1  Inc5000 Company List  Inc5000 Company List              1
# 1     NaN     2  Inc5000 Company List  Inc5000 Company List              2
# 2     NaN     3  Inc5000 Company List  Inc5000 Company List              3
#
#                                             _pageUrl     id  rank  workers  \
# 0  http://www.inc.com/inc5000list/json/inc5000_20...  22890     1      227
# 1  http://www.inc.com/inc5000list/json/inc5000_20...  25747     2      191
# 2  http://www.inc.com/inc5000list/json/inc5000_20...  25643     3      145
#
#                     company                       url     state_l state_s  \
# 0                      Fuhu                      fuhu  California      CA
# 1           Quest Nutrition           quest-nutrition  California      CA
# 2  Reliant Asset Management  reliant-asset-management    Virginia      VA
#
#          city          metro       growth    revenue  \
# 0  El Segundo    Los Angeles  158956.9106  195640000
# 1  El Segundo    Los Angeles   57347.9246   82640563
# 2   Arlington  Washington DC   55460.1646   85076502
#
#                        industry  yrs_on_list
# 0  Consumer Products & Services            2
# 1               Food & Beverage            1
# 2  Business Products & Services            1

# %%
gf = df.groupby('state_l', dropna=True)
gf.first()
# Out:
#                       _input  _num           _widgetName  \
# state_l
# Alabama                  NaN    20  Inc5000 Company List
# Alaska                   NaN  4220  Inc5000 Company List
# Arizona                  NaN     8  Inc5000 Company List
# Arkansas                 NaN   589  Inc5000 Company List
# California               NaN     1  Inc5000 Company List
# Colorado                 NaN    11  Inc5000 Company List
# Connecticut              NaN   314  Inc5000 Company List
# Delaware                 NaN   230  Inc5000 Company List
# District of Columbia     NaN    68  Inc5000 Company List
# Florida                  NaN    13  Inc5000 Company List
# Georgia                  NaN   147  Inc5000 Company List
# Hawaii                   NaN    16  Inc5000 Company List
# Idaho                    NaN   112  Inc5000 Company List
# Illinois                 NaN    51  Inc5000 Company List
# Indiana                  NaN    30  Inc5000 Company List
# Iowa                     NaN    40  Inc5000 Company List
# Kansas                   NaN    12  Inc5000 Company List
# Kentucky                 NaN   156  Inc5000 Company List
# Louisiana                NaN    38  Inc5000 Company List
# Maine                    NaN     6  Inc5000 Company List
# Maryland                 NaN    39  Inc5000 Company List
# Massachusetts            NaN     5  Inc5000 Company List
# Michigan                 NaN    35  Inc5000 Company List
# Minnesota                NaN   209  Inc5000 Company List
# Mississippi              NaN   210  Inc5000 Company List
# Missouri                 NaN    31  Inc5000 Company List
# Montana                  NaN   338  Inc5000 Company List
# Nebraska                 NaN   269  Inc5000 Company List
# Nevada                   NaN   272  Inc5000 Company List
# New Hampshire            NaN   161  Inc5000 Company List
# New Jersey               NaN    32  Inc5000 Company List
# New Mexico               NaN   179  Inc5000 Company List
# New York                 NaN    34  Inc5000 Company List
# North Carolina           NaN    10  Inc5000 Company List
# North Dakota             NaN  1855  Inc5000 Company List
# Ohio                     NaN    48  Inc5000 Company List
# Oklahoma                 NaN    44  Inc5000 Company List
# Oregon                   NaN     9  Inc5000 Company List
# Pennsylvania             NaN    27  Inc5000 Company List
# Puerto Rico              NaN  2163  Inc5000 Company List
# Rhode Island             NaN    53  Inc5000 Company List
# South Carolina           NaN   141  Inc5000 Company List
# South Dakota             NaN  1087  Inc5000 Company List
# Tennessee                NaN   281  Inc5000 Company List
# Texas                    NaN    21  Inc5000 Company List
# Utah                     NaN    86  Inc5000 Company List
# Vermont                  NaN   794  Inc5000 Company List
# Virginia                 NaN     3  Inc5000 Company List
# Washington               NaN    88  Inc5000 Company List
# West Virginia            NaN   268  Inc5000 Company List
# Wisconsin                NaN    36  Inc5000 Company List
#
#                                    _source  _resultNumber  \
# state_l
# Alabama               Inc5000 Company List             20
# Alaska                Inc5000 Company List           4220
# Arizona               Inc5000 Company List              8
# Arkansas              Inc5000 Company List            589
# California            Inc5000 Company List              1
# Colorado              Inc5000 Company List             11
# Connecticut           Inc5000 Company List            314
# Delaware              Inc5000 Company List            230
# District of Columbia  Inc5000 Company List             68
# Florida               Inc5000 Company List             13
# Georgia               Inc5000 Company List            147
# Hawaii                Inc5000 Company List             16
# Idaho                 Inc5000 Company List            112
# Illinois              Inc5000 Company List             51
# Indiana               Inc5000 Company List             30
# Iowa                  Inc5000 Company List             40
# Kansas                Inc5000 Company List             12
# Kentucky              Inc5000 Company List            156
# Louisiana             Inc5000 Company List             38
# Maine                 Inc5000 Company List              6
# Maryland              Inc5000 Company List             39
# Massachusetts         Inc5000 Company List              5
# Michigan              Inc5000 Company List             35
# Minnesota             Inc5000 Company List            209
# Mississippi           Inc5000 Company List            210
# Missouri              Inc5000 Company List             31
# Montana               Inc5000 Company List            338
# Nebraska              Inc5000 Company List            269
# Nevada                Inc5000 Company List            272
# New Hampshire         Inc5000 Company List            161
# New Jersey            Inc5000 Company List             32
# New Mexico            Inc5000 Company List            179
# New York              Inc5000 Company List             34
# North Carolina        Inc5000 Company List             10
# North Dakota          Inc5000 Company List           1855
# Ohio                  Inc5000 Company List             48
# Oklahoma              Inc5000 Company List             44
# Oregon                Inc5000 Company List              9
# Pennsylvania          Inc5000 Company List             27
# Puerto Rico           Inc5000 Company List           2163
# Rhode Island          Inc5000 Company List             53
# South Carolina        Inc5000 Company List            141
# South Dakota          Inc5000 Company List           1087
# Tennessee             Inc5000 Company List            281
# Texas                 Inc5000 Company List             21
# Utah                  Inc5000 Company List             86
# Vermont               Inc5000 Company List            794
# Virginia              Inc5000 Company List              3
# Washington            Inc5000 Company List             88
# West Virginia         Inc5000 Company List            268
# Wisconsin             Inc5000 Company List             36
#
#                                                                _pageUrl  \
# state_l
# Alabama               http://www.inc.com/inc5000list/json/inc5000_20...
# Alaska                http://www.inc.com/inc5000list/json/inc5000_20...
# Arizona               http://www.inc.com/inc5000list/json/inc5000_20...
# Arkansas              http://www.inc.com/inc5000list/json/inc5000_20...
# California            http://www.inc.com/inc5000list/json/inc5000_20...
# Colorado              http://www.inc.com/inc5000list/json/inc5000_20...
# Connecticut           http://www.inc.com/inc5000list/json/inc5000_20...
# Delaware              http://www.inc.com/inc5000list/json/inc5000_20...
# District of Columbia  http://www.inc.com/inc5000list/json/inc5000_20...
# Florida               http://www.inc.com/inc5000list/json/inc5000_20...
# Georgia               http://www.inc.com/inc5000list/json/inc5000_20...
# Hawaii                http://www.inc.com/inc5000list/json/inc5000_20...
# Idaho                 http://www.inc.com/inc5000list/json/inc5000_20...
# Illinois              http://www.inc.com/inc5000list/json/inc5000_20...
# Indiana               http://www.inc.com/inc5000list/json/inc5000_20...
# Iowa                  http://www.inc.com/inc5000list/json/inc5000_20...
# Kansas                http://www.inc.com/inc5000list/json/inc5000_20...
# Kentucky              http://www.inc.com/inc5000list/json/inc5000_20...
# Louisiana             http://www.inc.com/inc5000list/json/inc5000_20...
# Maine                 http://www.inc.com/inc5000list/json/inc5000_20...
# Maryland              http://www.inc.com/inc5000list/json/inc5000_20...
# Massachusetts         http://www.inc.com/inc5000list/json/inc5000_20...
# Michigan              http://www.inc.com/inc5000list/json/inc5000_20...
# Minnesota             http://www.inc.com/inc5000list/json/inc5000_20...
# Mississippi           http://www.inc.com/inc5000list/json/inc5000_20...
# Missouri              http://www.inc.com/inc5000list/json/inc5000_20...
# Montana               http://www.inc.com/inc5000list/json/inc5000_20...
# Nebraska              http://www.inc.com/inc5000list/json/inc5000_20...
# Nevada                http://www.inc.com/inc5000list/json/inc5000_20...
# New Hampshire         http://www.inc.com/inc5000list/json/inc5000_20...
# New Jersey            http://www.inc.com/inc5000list/json/inc5000_20...
# New Mexico            http://www.inc.com/inc5000list/json/inc5000_20...
# New York              http://www.inc.com/inc5000list/json/inc5000_20...
# North Carolina        http://www.inc.com/inc5000list/json/inc5000_20...
# North Dakota          http://www.inc.com/inc5000list/json/inc5000_20...
# Ohio                  http://www.inc.com/inc5000list/json/inc5000_20...
# Oklahoma              http://www.inc.com/inc5000list/json/inc5000_20...
# Oregon                http://www.inc.com/inc5000list/json/inc5000_20...
# Pennsylvania          http://www.inc.com/inc5000list/json/inc5000_20...
# Puerto Rico           http://www.inc.com/inc5000list/json/inc5000_20...
# Rhode Island          http://www.inc.com/inc5000list/json/inc5000_20...
# South Carolina        http://www.inc.com/inc5000list/json/inc5000_20...
# South Dakota          http://www.inc.com/inc5000list/json/inc5000_20...
# Tennessee             http://www.inc.com/inc5000list/json/inc5000_20...
# Texas                 http://www.inc.com/inc5000list/json/inc5000_20...
# Utah                  http://www.inc.com/inc5000list/json/inc5000_20...
# Vermont               http://www.inc.com/inc5000list/json/inc5000_20...
# Virginia              http://www.inc.com/inc5000list/json/inc5000_20...
# Washington            http://www.inc.com/inc5000list/json/inc5000_20...
# West Virginia         http://www.inc.com/inc5000list/json/inc5000_20...
# Wisconsin             http://www.inc.com/inc5000list/json/inc5000_20...
#
#                          id  rank  workers  \
# state_l
# Alabama               25398    20       44
# Alaska                26261  4220       38
# Arizona               25413     8      130
# Arkansas              26172   589       87
# California            22890     1      227
# Colorado              25231    11      113
# Connecticut           21000   314      245
# Delaware              25449   230        4
# District of Columbia  22983    68       34
# Florida               22892    13      153
# Georgia               26517   147      140
# Hawaii                26535    16       34
# Idaho                 26464   112       12
# Illinois              26092    51       32
# Indiana               26342    30      200
# Iowa                  25306    40        4
# Kansas                26450    12      135
# Kentucky              25004   156       29
# Louisiana             25755    38       25
# Maine                 22913     6       50
# Maryland              25634    39        1
# Massachusetts         26182     5       92
# Michigan              25522    35       55
# Minnesota             25565   209      120
# Mississippi           23172   210       25
# Missouri              24949    31       33
# Montana               26524   338        3
# Nebraska              22994   269      110
# Nevada                26438   272       22
# New Hampshire         26268   161       15
# New Jersey            25188    32      176
# New Mexico            25141   179       16
# New York              25357    34      140
# North Carolina        25861    10       11
# North Dakota          23938  1855       67
# Ohio                  25931    48       17
# Oklahoma              26179    44      147
# Oregon                26079     9      264
# Pennsylvania          25360    27       27
# Puerto Rico           26617  2163      293
# Rhode Island          17948    53     1106
# South Carolina        25749   141       81
# South Dakota          23743  1087       22
# Tennessee             26283   281       40
# Texas                 25290    21       12
# Utah                  24946    86     1250
# Vermont               26235   794      130
# Virginia              25643     3      145
# Washington            22933    88      150
# West Virginia         25622   268       47
# Wisconsin             22949    36       61
#
#                                                    company  \
# state_l
# Alabama                                   BES Design/Build
# Alaska                                         Spawn Ideas
# Arizona                                   Plexus Worldwide
# Arkansas                                   Collective Bias
# California                                            Fuhu
# Colorado                                        Minute Key
# Connecticut                                          Datto
# Delaware                                       X5 Networks
# District of Columbia                              Viderity
# Florida                                      The HCI Group
# Georgia                     Residential Capital Management
# Hawaii                                      Asentra Health
# Idaho                                             Ataraxis
# Illinois                                       MAX Digital
# Indiana                                   HighPoint Global
# Iowa                                         Choice Energy
# Kansas                                           Sainstore
# Kentucky                                  Legion Logistics
# Louisiana                           Pontchartrain Partners
# Maine                                       Provider Power
# Maryland              Team Extreme Marketing International
# Massachusetts                        Acacia Communications
# Michigan                                    Retail Capital
# Minnesota                                       PerformTel
# Mississippi                        R.J. Allen & Associates
# Missouri                                           AdKarma
# Montana                                   Glacier Payments
# Nebraska                                              Hudl
# Nevada                                         Luxe Royale
# New Hampshire                                   RocketDrop
# New Jersey                                          Axtria
# New Mexico                                         InkSoft
# New York                                   Centric Digital
# North Carolina                                 Go Energies
# North Dakota                                 RealTruck.com
# Ohio                                      Ohio Investments
# Oklahoma                                 MCSG Technologies
# Oregon                                              Vacasa
# Pennsylvania                                        WeVeel
# Puerto Rico                        TrueNorth (Guaynabo PR)
# Rhode Island                                  Alex and Ani
# South Carolina                                    PureCars
# South Dakota                                    Click Rain
# Tennessee                                          Entrada
# Texas                                      Simpler Trading
# Utah                                       Connexion Point
# Vermont                                 The Hermitage Club
# Virginia                          Reliant Asset Management
# Washington                                            TUNE
# West Virginia               Allegheny Science & Technology
# Wisconsin                                   Restore Health
#
#                                                        url state_s  \
# state_l
# Alabama                                    bes-designbuild      AL
# Alaska                                         spawn-ideas      AK
# Arizona                                   plexus-worldwide      AZ
# Arkansas                                   collective-bias      AR
# California                                            fuhu      CA
# Colorado                                        minute-key      CO
# Connecticut                                          datto      CT
# Delaware                                       x5-networks      DE
# District of Columbia                              viderity      DC
# Florida                                      the-hci-group      FL
# Georgia                     residential-capital-management      GA
# Hawaii                                      asentra-health      HI
# Idaho                                             ataraxis      ID
# Illinois                                       max-digital      IL
# Indiana                                   highpoint-global      IN
# Iowa                                         choice-energy      IA
# Kansas                                           sainstore      KS
# Kentucky                                  legion-logistics      KY
# Louisiana                           pontchartrain-partners      LA
# Maine                                       provider-power      ME
# Maryland              team-extreme-marketing-international      MD
# Massachusetts                        acacia-communications      MA
# Louisiana             1.843578  1.0  1.00  2.0  3.00   8.0
# Maine                 1.869360  1.0  1.00  2.0  3.00   8.0
# Maryland              1.986039  1.0  1.00  2.0  4.00  10.0
# Massachusetts         2.002465  1.0  1.00  2.0  4.00   9.0
# Michigan              2.049710  1.0  1.00  2.0  4.00   8.0
# Minnesota             1.994502  1.0  1.00  2.0  4.00   8.0
# Mississippi           1.658312  1.0  1.75  2.0  4.00   6.0
# Missouri              1.791783  1.0  1.00  2.0  3.00   7.0
# Montana               1.095445  1.0  1.00  1.0  3.00   3.0
# Nebraska              2.061232  1.0  1.00  2.0  4.00   8.0
# Nevada                1.500538  1.0  1.00  2.0  4.00   6.0
# New Hampshire         2.266355  1.0  1.00  2.0  3.00   8.0
# New Jersey            1.970264  1.0  1.00  2.0  4.00   9.0
# New Mexico            2.000000  1.0  1.00  1.0  1.75   6.0
# New York              1.941669  1.0  1.00  2.0  3.00   9.0
# North Carolina        1.912653  1.0  1.00  3.0  4.00   8.0
# North Dakota          2.097618  1.0  2.00  2.5  3.00   7.0
# Ohio                  2.337075  1.0  1.00  3.0  4.50  11.0
# Oklahoma              2.591764  1.0  1.00  2.5  4.00   9.0
# Oregon                1.986842  1.0  1.00  2.0  4.00   8.0
# Pennsylvania          2.301377  1.0  1.00  2.0  4.50  10.0
# Puerto Rico           0.707107  1.0  1.25  1.5  1.75   2.0
# Rhode Island          2.827127  1.0  1.00  2.0  5.00  10.0
# South Carolina        1.747918  1.0  1.00  2.0  3.00   8.0
# South Dakota          0.000000  2.0  2.00  2.0  2.00   2.0
# Tennessee             2.264161  1.0  1.00  2.0  4.00   9.0
# Texas                 1.870156  1.0  1.00  2.0  4.00  10.0
# Utah                  1.967033  1.0  1.00  2.0  3.00  10.0
# Vermont               2.645751  1.0  3.00  5.0  5.50   6.0
# Virginia              1.922123  1.0  1.00  2.0  4.00  10.0
# Washington            1.913948  1.0  1.00  2.0  4.00   8.0
# West Virginia         0.000000  1.0  1.00  1.0  1.00   1.0
# Wisconsin             2.291446  1.0  1.00  2.0  4.00  10.0
#
# [51 rows x 72 columns]

# %%
#Here's a bar graph of the number of workers in each state in the US.
x,y='state_l','workers'
title="Bar Plot of {}".format(y)
plt.figure(figsize=(20, 6))
plt.bar(df[x], df[y])
plt.xlabel(x)
# Rotate x-axis label
plt.xticks(rotation=90)
plt.ylabel(y)
plt.title(title)
plt.show()

# %%
#Here's a bar graph of the number of workers in each state in the US.
x,y = 'state_l', 'revenue'
plt.figure(figsize=(20, 6))
plt.bar(df[x], df[y])
plt.xlabel(x)
# Rotate x-axis label
plt.xticks(rotation=90)
plt.ylabel(y)
plt.title('Bar Plot of {}'.format(x))
plt.show()

# %%
# assign axis variables
x1,y1= 'state_l', 'revenue'
x2,y2= 'state_l','workers'

# Create the first figure
fig1, ax1 = plt.subplots(figsize=(20, 6))
ax1.bar(df[x1], df[y1], color='skyblue', edgecolor='black')
ax1.set_xlabel(x1)
ax1.set_ylabel(y1)
ax1.set_title('Bar Plot of {}'.format(y1))
ax1.set_xticklabels(df[x], rotation=90)

# Create the second figure
fig2, ax2 = plt.subplots(figsize=(20, 6))
ax2.bar(df[x2], df[y2], color='lightgreen', edgecolor='black')
ax2.set_xlabel(x2)
ax2.set_ylabel(y2)
ax2.set_title('Bar Plot of {}'.format(y2))
ax2.set_xticklabels(df[x2], rotation=90)

# Show the first figure
# plt.figure(fig1.number)
# plt.show()

# fig1.show()

# Show the second figure
# plt.figure(fig2.number)
# plt.show()
# Out:
# /tmp/ipykernel_2049/3932051157.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df[x], rotation=90)
# /tmp/ipykernel_2049/3932051157.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(df[x2], rotation=90)
# [Text(0, 0, 'California'),
#  Text(1, 0, 'California'),
#  Text(2, 0, 'Virginia'),
#  Text(3, 0, 'California'),
#  Text(4, 0, 'Massachusetts'),
#  Text(5, 0, 'Maine'),
#  Text(6, 0, 'California'),
#  Text(7, 0, 'Arizona'),
#  Text(8, 0, 'Oregon'),
#  Text(9, 0, 'North Carolina'),
#  Text(10, 0, 'Colorado'),
#  Text(11, 0, 'Kansas'),
#  Text(12, 0, 'Florida'),
#  Text(13, 0, 'Florida'),
#  Text(14, 0, 'North Carolina'),
#  Text(15, 0, 'Hawaii'),
#  Text(16, 0, 'California'),
#  Text(17, 0, 'Virginia'),
#  Text(18, 0, 'Arizona'),
#  Text(19, 0, 'Alabama'),
#  Text(20, 0, 'Texas'),
#  Text(21, 0, 'Virginia'),
#  Text(22, 0, 'Arizona'),
#  Text(23, 0, 'Texas'),
#  Text(24, 0, 'Florida'),
#  Text(25, 0, 'Florida'),
#  Text(26, 0, 'Pennsylvania'),
#  Text(27, 0, 'California'),
#  Text(28, 0, 'Arizona'),
#  Text(29, 0, 'Indiana'),
#  Text(30, 0, 'Missouri'),
#  Text(31, 0, 'New Jersey'),
#  Text(32, 0, 'California'),
#  Text(33, 0, 'New York'),
#  Text(34, 0, 'Michigan'),
#  Text(35, 0, 'Wisconsin'),
#  Text(36, 0, 'Texas'),
#  Text(37, 0, 'Louisiana'),
#  Text(38, 0, 'Maryland'),
#  Text(39, 0, 'Iowa'),
#  Text(40, 0, 'New York'),
#  Text(41, 0, 'California'),
#  Text(42, 0, 'Alabama'),
#  Text(43, 0, 'Oklahoma'),
#  Text(44, 0, 'Texas'),
#  Text(45, 0, 'Wisconsin'),
#  Text(46, 0, 'Michigan'),
#  Text(47, 0, 'Ohio'),
#  Text(48, 0, 'New York'),
#  Text(49, 0, 'Florida'),
#  Text(50, 0, 'Illinois')]

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.36.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (0.27.0)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Downloading openai-1.36.0-py3-none-any.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.7/328.7 kB 10.8 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 14.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.2 MB/s eta 0:00:00:00:01
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: tqdm, pydantic-core, distro, annotated-types, pydantic, openai
# Successfully installed annotated-types-0.7.0 distro-1.9.0 openai-1.36.0 pydantic-2.8.2 pydantic-core-2.20.1 tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI

client = OpenAI(api_key='your-api-key')
print("OpenAIClient initialized...")

# Create specialized Assistants each tailored to analyze aspects from their fields of expertise.
assistants = {
    "economist": client.beta.assistants.create(
        name="Economic Analyst",
        model="gpt-4-turbo",
        tools=[{"type": "code_interpreter"}]
    ),
    "environmentalist": client.beta.assistants.create(
        name="Environmental Scientist",
        model="gpt-4-turbo",
        tools=[{"type": "code_interpreter"}]
    ),
    "ethicist": client.beta.assistants.create(
        name="Technology Ethicist",
        model="gpt-4-turbo",
        tools=[{"type": "code_interpreter"}]
    )
}
print("Panel initialized! ", assistants.keys())

# create thread to track prompts and responses.
thread = client.beta.threads.create()
print("Thread initialized...")

# returns an AI response from user prompt.
user_prompt = "Discuss the impact of recent technology innovations on both the economy and environment."
client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content=user_prompt
)
print("User prompt: ", user_prompt)
# Out:
# OpenAIClient initialized...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[1], line 8
#       4 print("OpenAIClient initialized...")
#       6 # Create specialized Assistants each tailored to analyze aspects from their fields of expertise.
#       7 assistants = {
# ----> 8     "economist": client.beta.assistants.create(
#       9         name="Economic Analyst",
#      10         model="gpt-4-turbo",
#      11         tools=[{"type": "code_interpreter"}]
#      12     ),
#      13     "environmentalist": client.beta.assistants.create(
#      14         name="Environmental Scientist",
#      15         model="gpt-4-turbo",
#      16         tools=[{"type": "code_interpreter"}]
#      17     ),
#      18     "ethicist": client.beta.assistants.create(
#      19         name="Technology Ethicist",
#      20         model="gpt-4-turbo",
#      21         tools=[{"type": "code_interpreter"}]
#      22     )
#      23 }
#      24 print("Panel initialized! ", assistants.keys())
#      26 # create thread to track prompts and responses.
#
# File ~/.python/current/lib/python3.10/site-packages/openai/resources/beta/assistants.py:158, in Assistants.create(self, model, description, instructions, metadata, name, response_format, temperature, tool_resources, tools, top_p, extra_headers, extra_query, extra_body, timeout)
#      92 """
#      93 Create an assistant with a model and instructions.
#      94
#    (...)
#     155   timeout: Override the client-level default timeout for this request, in seconds
#     156 """
#     157 extra_headers = {"OpenAI-Beta": "assistants=v2", **(extra_headers or {})}
# --> 158 return self._post(
#     159     "/assistants",
#     160     body=maybe_transform(
#     161         {
#     162             "model": model,
#     163             "description": description,
#     164             "instructions": instructions,
#     165             "metadata": metadata,
#     166             "name": name,
#     167             "response_format": response_format,
#     168             "temperature": temperature,
#     169             "tool_resources": tool_resources,
#     170             "tools": tools,
#     171             "top_p": top_p,
#     172         },
#     173         assistant_create_params.AssistantCreateParams,
#     174     ),
#     175     options=make_request_options(
#     176         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     177     ),
#     178     cast_to=Assistant,
#     179 )
#
# File ~/.python/current/lib/python3.10/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.python/current/lib/python3.10/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.python/current/lib/python3.10/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: your-api-key. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
